# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('whitegrid')
import statsmodels.api as sm

# %%
mat_df = pd.read_csv('new_student-mat.csv')
mat_df.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher  \
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        6   5   6   6
# 1  ...      5        3      3     1     1      3        4   5   5   6
# 2  ...      4        3      2     2     3      3       10   7   8  10
# 3  ...      3        2      2     1     1      5        2  15  14  15
# 4  ...      4        3      2     1     2      5        4   6  10  10
# 5  ...      5        4      2     1     2      5       10  15  15  15
# 6  ...      4        4      4     1     1      3        0  12  12  11
# 7  ...      4        1      4     1     1      1        6   6   5   6
# 8  ...      4        2      2     1     1      1        0  16  18  19
# 9  ...      5        5      1     1     1      5        0  14  15  15
#
# [10 rows x 33 columns]

# %%
mat_df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
por_df = pd.read_csv('new_student-por.csv')
por_df.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher  \
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        4   0  11  11
# 1  ...      5        3      3     1     1      3        2   9  11  11
# 2  ...      4        3      2     2     3      3        6  12  13  12
# 3  ...      3        2      2     1     1      5        0  14  14  14
# 4  ...      4        3      2     1     2      5        0  11  13  13
# 5  ...      5        4      2     1     2      5        6  12  12  13
# 6  ...      4        4      4     1     1      3        0  13  12  13
# 7  ...      4        1      4     1     1      1        2  10  13  13
# 8  ...      4        2      2     1     1      1        0  15  16  17
# 9  ...      5        5      1     1     1      5        0  12  12  13
#
# [10 rows x 33 columns]

# %%
por_df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df = pd.concat([mat_df,por_df])
df.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher  \
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        6   5   6   6
# 1  ...      5        3      3     1     1      3        4   5   5   6
# 2  ...      4        3      2     2     3      3       10   7   8  10
# 3  ...      3        2      2     1     1      5        2  15  14  15
# 4  ...      4        3      2     1     2      5        4   6  10  10
# 5  ...      5        4      2     1     2      5       10  15  15  15
# 6  ...      4        4      4     1     1      3        0  12  12  11
# 7  ...      4        1      4     1     1      1        6   6   5   6
# 8  ...      4        2      2     1     1      1        0  16  18  19
# 9  ...      5        5      1     1     1      5        0  14  15  15
#
# [10 rows x 33 columns]

# %%
#add grade to the final grade into categorical variable(good, fair and poor)
df['final_grade'] = 'na'
df.loc[(df.G3 >= 15)& (df.G3 <=20), 'final_grade'] = 'good'
df.loc[(df.G3 >= 10)& (df.G3 <=14), 'final_grade'] = 'fair'
df.loc[(df.G3 >= 0)& (df.G3 <=9), 'final_grade'] = 'poor'
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher  \
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... freetime goout  Dalc  Walc  health absences  G1  G2  G3 final_grade
# 0    ...        3     4     1     1       3        6   5   6   6        poor
# 1    ...        3     3     1     1       3        4   5   5   6        poor
# 2    ...        3     2     2     3       3       10   7   8  10        fair
# 3    ...        2     2     1     1       5        2  15  14  15        good
# 4    ...        3     2     1     2       5        4   6  10  10        fair
# ..   ...      ...   ...   ...   ...     ...      ...  ..  ..  ..         ...
# 644  ...        4     2     1     2       5        4  10  11  10        fair
# 645  ...        3     4     1     1       1        4  15  15  16        good
# 646  ...        1     1     1     1       5        6  11  12   9        poor
# 647  ...        4     5     3     4       2        6  10  10  10        fair
# 648  ...        4     1     3     4       5        4  10  11  11        fair
#
# [1044 rows x 34 columns]

# %% [markdown]
# <h2 style = 'text-align: center'>Data Analysis</h2>

# %%
#Frequency of the final_grade
df['final_grade'].value_counts().plot(kind = 'bar')
plt.title('Final Grade - Number of Students',fontsize=20)
plt.xlabel('Final Grade', fontsize=16)
plt.ylabel('Number of Student', fontsize=16)
# Out:
# Text(0, 0.5, 'Number of Student')

# %%
#Correlation heatmap
numerical_cols = df.select_dtypes(include=['float64', 'int64']).columns.tolist()
num_df = df[numerical_cols]

corr_matrix = num_df.corr()

sns.heatmap(corr_matrix, cmap='coolwarm', annot=True, fmt='.2f', annot_kws={'fontsize': 8})
# Out:
# <Axes: >

# %%
#relationship vs no relationship students
index = ['poor','fair','good']
romance_tab = pd.crosstab(index=df.final_grade, columns=df.romantic)
romance = romance_tab.reindex(index)

# %%
plt.figure()
romance.plot.bar(colormap="PiYG_r", fontsize=16, figsize=(8,8))
plt.title('Final Grade By Romantic Status', fontsize=20)
plt.ylabel('Number of Student Counts ', fontsize=16)
plt.xlabel('Final Grade', fontsize=16)
plt.show()

# %%
#Test hyphothesis
import statsmodels.api as sm
romance_table = sm.stats.Table(romance_tab)
romance_rslt = romance_table.test_nominal_association()
romance_rslt.pvalue
print('p-value:',romance_rslt.pvalue,'\nHyphothesis Testing confirmed, romantic status has a significant correlation with final grade.')
# Out:
# p-value: 0.038810128743959726
# Hyphothesis Testing confirmed, romantic status has a significant correlation with final grade.

# %%
#Final Grade By Alcohol Consumption
perc = (lambda col: col/col.sum())
alc_tab1 = pd.crosstab(index=df.final_grade, columns=df.Walc)
alc_tab = np.log(alc_tab1)
alc_perc = alc_tab.apply(perc).reindex(index)

# %%
alc_perc.plot.bar(colormap="Reds", figsize=(10,8), fontsize=16)
plt.title('Final Grade By Weekend Alcohol Consumption', fontsize=20)
plt.ylabel('Percentage of Logarithm Student Counts', fontsize=16)
plt.xlabel('Final Grade', fontsize=16)
# Out:
# Text(0.5, 0, 'Final Grade')

# %%
#Test hyphothesis
alc_table = sm.stats.Table(alc_tab1)
alc_rslt = alc_table.test_nominal_association()
print('p-value:',alc_rslt.pvalue,'\nHyphothesis Testing confirmed, weekend alcohol consumption has a significant correlation with final grade.')
# Out:
# p-value: 0.007592294056368298
# Hyphothesis Testing confirmed, weekend alcohol consumption has a significant correlation with final grade.

# %%
#Final Grade By Parents Education Level
X_edu = df[['Medu','Fedu']]
y_edu = df.G3
edu = sm.OLS(y_edu, X_edu)
results_edu = edu.fit()
results_edu.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     G3   R-squared (uncentered):                   0.814
# Model:                            OLS   Adj. R-squared (uncentered):              0.814
# Method:                 Least Squares   F-statistic:                              2287.
# Date:                Sat, 20 May 2023   Prob (F-statistic):                        0.00
# Time:                        19:10:30   Log-Likelihood:                         -3194.8
# No. Observations:                1044   AIC:                                      6394.
# Df Residuals:                    1042   BIC:                                      6403.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Medu           2.4078      0.166     14.527      0.000       2.083       2.733
# Fedu           1.5746      0.179      8.806      0.000       1.224       1.926
# ==============================================================================
# Omnibus:                       35.858   Durbin-Watson:                   1.631
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               39.773
# Skew:                          -0.427   Prob(JB):                     2.31e-09
# Kurtosis:                       3.430   Cond. No.                         5.72
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# OLS tells that parents' education level has a positive correlation with students' final score. Comparatively, mother's education level has bigger influence than father's education level

# %%
#Final Grade By Frequency Of Going Out
plt.figure(figsize=(6,10))
sns.boxplot(x='goout', y='G3', data=df, palette='hot')
plt.title('Final Grade By Frequency of Going Out', fontsize=20)
plt.ylabel('Final Score', fontsize=16)
plt.xlabel('Frequency of Going Out', fontsize=16)
# Out:
# Text(0.5, 0, 'Frequency of Going Out')

# %%
#Test Hyphothesis
out_tab = pd.crosstab(index=df.final_grade, columns=df.goout)
out_perc = out_tab.apply(perc).reindex(index)

out_table = sm.stats.Table(out_tab)
out_rslt = out_table.test_nominal_association()
print('p-value:',out_rslt.pvalue,'''\nHyphothesis Testing confirmed, the frequency of going out with friends has a significant correlation with students' final performance.''')
# Out:
# p-value: 4.365198328282194e-05
# Hyphothesis Testing confirmed, the frequency of going out with friends has a significant correlation with students' final performance.

# %%
#Final Grade By Desire To Go To College
higher_tab = pd.crosstab(index=df.final_grade, columns=df.higher)
higher_perc = higher_tab.apply(perc).reindex(index)

higher_perc.plot.bar(colormap="Reds", figsize=(14,6), fontsize=16)
plt.title('Final Grade By Desire to Receive Higher Education', fontsize=20)
plt.xlabel('Final Grade', fontsize=16)
plt.ylabel('Percentage of Student', fontsize=16)
# Out:
# Text(0, 0.5, 'Percentage of Student')

# %%
#Test Hyphothesis
higher_table = sm.stats.Table(higher_tab)
higher_rslt = higher_table.test_nominal_association()
print('p-value:',higher_rslt.pvalue,'''\nHyphothesis Testing confirmed, the desire of going to college has a significant correlation with students' final performance.''')
# Out:
# p-value: 2.2470914018413168e-13
# Hyphothesis Testing confirmed, the desire of going to college has a significant correlation with students' final performance.

# %%
ad_tab1 = pd.crosstab(index=df.final_grade, columns=df.address)
ad_tab = np.log(ad_tab1)
ad_perc = ad_tab.apply(perc).reindex(index)

ad_perc.plot.bar(colormap="RdYlGn_r", fontsize=16, figsize=(8,6))
plt.title('Final Grade By Living Area', fontsize=20)
plt.ylabel('Percentage of Logarithm Student#', fontsize=16)
plt.xlabel('Final Grade', fontsize=16)
# Out:
# Text(0.5, 0, 'Final Grade')

# %%
#Test Hyphothesis
ad_table = sm.stats.Table(ad_tab1)
ad_rslt = ad_table.test_nominal_association()
print('p-value:',ad_rslt.pvalue,"""\nHyphothesis Testing confirmed, the frequency of going out with friends has a significant correlation with students' final performance.""")
# Out:
# p-value: 0.007608910517873602
# Hyphothesis Testing confirmed, the frequency of going out with friends has a significant correlation with students' final performance.

# %% [markdown]
# <h2 style = 'text-align: center'>Model</h2>

# %% [markdown]
# ***Multi Linear Regression***

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn import preprocessing
data = df

le = preprocessing.LabelEncoder()
data.school = le.fit_transform(data.school)
data.sex = le.fit_transform(data.sex)

X1 = data[['school','sex','age','Medu','Fedu','studytime','freetime','goout','Walc','health','absences','G1','G2']]
y1 = data['G3']

# Add a constant to the independent variables for Model
X1 = sm.add_constant(X1)

# Calculate the VIF values for Model
vif1 = pd.DataFrame()
vif1["VIF Factor"] = [variance_inflation_factor(X1.values, i) for i in range(X1.shape[1])]
vif1["features"] = X1.columns

# Fit Model using OLS regression
model1 = sm.OLS(y1, X1).fit()

# Print the summary of Model and the calculated VIF values
print("Model 1(Multi Linear Regression):")
print(model1.summary())
print("VIF Values:")
print(vif1)
# Out:
# Model 1(Multi Linear Regression):
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     G3   R-squared:                       0.835
# Model:                            OLS   Adj. R-squared:                  0.833
# Method:                 Least Squares   F-statistic:                     400.2
# Date:                Sat, 20 May 2023   Prob (F-statistic):               0.00
# Time:                        19:10:43   Log-Likelihood:                -1952.5
# No. Observations:                1044   AIC:                             3933.
# Df Residuals:                    1030   BIC:                             4002.
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1987      0.774      0.257      0.797      -1.319       1.717
# school         0.1568      0.120      1.304      0.193      -0.079       0.393
# sex           -0.0677      0.110     -0.617      0.537      -0.283       0.147
# age           -0.0800      0.041     -1.929      0.054      -0.161       0.001
# Medu           0.0003      0.059      0.005      0.996      -0.115       0.115
# Fedu          -0.0479      0.059     -0.816      0.414      -0.163       0.067
# studytime     -0.0382      0.063     -0.602      0.547      -0.163       0.086
# freetime      -0.0066      0.051     -0.128      0.898      -0.107       0.094
# goout          0.0098      0.049      0.198      0.843      -0.087       0.107
# Walc           0.0038      0.045      0.084      0.933      -0.085       0.092
# health         0.0047      0.035      0.133      0.895      -0.064       0.074
# absences       0.0276      0.008      3.317      0.001       0.011       0.044
# G1             0.1430      0.032      4.405      0.000       0.079       0.207
# G2             0.9690      0.029     33.101      0.000       0.912       1.026
# ==============================================================================
# Omnibus:                      671.727   Durbin-Watson:                   1.795
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8435.853
# Skew:                          -2.803   Prob(JB):                         0.00
# Kurtosis:                      15.748   Cond. No.                         393.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# VIF Values:
#     VIF Factor   features
# 0   250.005460      const
# 1     1.164470     school
# 2     1.231873        sex
# 3     1.103641        age
# 4     1.812970       Medu
# 5     1.734846       Fedu
# 6     1.168114  studytime
# 7     1.167468   freetime
# 8     1.354355      goout
# 9     1.400386       Walc
# 10    1.050963     health
# 11    1.110317   absences
# 12    3.913730         G1
# 13    3.859458         G2

# %% [markdown]
# ***Logistic Regression***

# %%
df_model = df.copy()
df_model = df_model.drop(['G3'], axis=1)

# %%
#Encode final_grade
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
df_model.final_grade = le.fit_transform(df_model.final_grade)

# %%
#train_test_split dataset
from sklearn.model_selection import train_test_split
X = df_model.drop('final_grade',axis=1) 
y = df_model.final_grade
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)

# %%
# get dummy varibles 
X_train = pd.get_dummies(X_train)
X_test = pd.get_dummies(X_test)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(multi_class='multinomial', solver='newton-cg',fit_intercept=True)

# %%
# find optimal # of features to use in the model
from sklearn.feature_selection import SelectKBest, chi2

ks=[]
for i in range(1,57):
    sk = SelectKBest(chi2, k=i)
    x_new = sk.fit_transform(X_train,y_train)
    x_new_test=sk.fit_transform(X_test,y_test)
    l = lr.fit(x_new, y_train)
    ll = l.score(x_new_test, y_test)
    ks.append(ll)  
    
ks = pd.Series(ks)
ks = ks.reindex(list(range(1,57)))

# %%
sk = SelectKBest(chi2, k=8)
x_new = sk.fit_transform(X_train,y_train)
x_new_test=sk.fit_transform(X_test,y_test)
lr = lr.fit(x_new, y_train)
print("Logistic Regression Model Score" , ":" , lr.score(x_new, y_train))
print('Model parameters:', lr.get_params())
print('Model coefficients:', lr.coef_)
print('Model intercept:', lr.intercept_)
# Out:
# Logistic Regression Model Score : 0.8835616438356164
# Model parameters: {'C': 1.0, 'class_weight': None, 'dual': False, 'fit_intercept': True, 'intercept_scaling': 1, 'l1_ratio': None, 'max_iter': 100, 'multi_class': 'multinomial', 'n_jobs': None, 'penalty': 'l2', 'random_state': None, 'solver': 'newton-cg', 'tol': 0.0001, 'verbose': 0, 'warm_start': False}
# Model coefficients: [[-0.13176715 -0.05729061  0.05015072 -0.00594963  0.0750156  -0.23563724
#    0.14307024 -0.22889849]
#  [-0.30232576 -0.22888765 -0.11603917 -0.0259406   0.33321423  1.97107985
#   -0.26032421 -0.17755944]
#  [ 0.43409291  0.28617826  0.06588845  0.03189023 -0.40822984 -1.73544261
#    0.11725398  0.40645793]]
# Model intercept: [  5.92837035 -28.14896236  22.22059201]
